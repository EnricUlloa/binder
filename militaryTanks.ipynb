# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /srv/conda/envs/notebook/lib/python3.10/site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from scikit-learn) (1.25.0)
# Requirement already satisfied: scipy>=1.6.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from scikit-learn) (3.6.0)

# %%
import pandas as pd
import seaborn as sns
df = pd.read_csv("militaryTanks.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Model Name                      18 non-null     object
#  1   Origin Country                  18 non-null     object
#  2   Crew                            18 non-null     int64
#  3   Range (km)                      18 non-null     int64
#  4   Max Road Speed (km/hr)          18 non-null     float64
#  5   Power-to-weight ratio (h.p./t)  16 non-null     float64
#  6   Length (m)                      18 non-null     float64
#  7   Width (m)                       18 non-null     float64
#  8   Height (m)                      18 non-null     float64
#  9   Engine Power (hp)               18 non-null     int64
#  10  Engine Type                     18 non-null     object
#  11  Weight (in Tons)                18 non-null     float64
#  12  Gradient (in %)                 18 non-null     int64
#  13  Side Slope (in %)               18 non-null     int64
#  14  Vertical Step (m)               18 non-null     float64
#  15  Trench (m)                      18 non-null     float64
#  16  Fording (m)                     18 non-null     float64
#  17  Fording (with preparation)      17 non-null     object
#  18  Depression (Elevation Min)      15 non-null     float64
#  19  Elevation (Elevation Max)       15 non-null     float64
#  20  Traverse Range                  18 non-null     int64
#  21  Manufactured By                 16 non-null     object
#  22  Launch Year                     17 non-null     float64
#  23  Main Weapon Caliber             18 non-null     int64
#  24  Ammunition Main Weapon          18 non-null     int64
#  25  Auxiliary Gun Caliber           18 non-null     float64
#  26  Ammunition Auxiliary Gun        15 non-null     float64
#  27  AA Gun Caliber                  18 non-null     float64
#  28  Ammunition AA Gun               15 non-null     float64
# dtypes: float64(16), int64(8), object(5)
# memory usage: 4.2+ KB

# %% [markdown]
# Con el "df.info()" muestro las variables que tiene este dataset.

# %%
len(df)
# Out:
# 18

# %% [markdown]
# Con el "len(df)" lo que hacemos es ver la longitud del dataset.

# %%
df.head()
# Out:
#          Model Name Origin Country  Crew  Range (km)  Max Road Speed (km/hr)  \
# 0       MB-3 Tamoyo         Brazil     4         550                    67.0
# 1        Leopard C2   West Germany     4         600                    65.0
# 2  Leopard 2A4M CAN   West Germany     4         400                    68.0
# 3              VT-4          China     3         500                    70.0
# 4          MBT-3000          China     3         500                    70.0
#
#    Power-to-weight ratio (h.p./t)  Length (m)  Width (m)  Height (m)  \
# 0                           18.18        8.76       3.20         2.5
# 1                           21.43        9.50       3.37         2.7
# 2                           26.16        9.61       3.75         3.0
# 3                           25.00       10.10       3.40         2.3
# 4                           25.00       10.10       3.40         2.3
#
#    Engine Power (hp)  ... Elevation (Elevation Max)  Traverse Range  \
# 0                500  ...                      18.0             360
# 1                830  ...                      20.0             360
# 2               1500  ...                      20.0             360
# 3               1300  ...                       NaN             360
# 4               1300  ...                       NaN             360
#
#                        Manufactured By  Launch Year  Main Weapon Caliber  \
# 0  Bernardini S/A Industria e Comercio       1983.0                   90
# 1                              Porsche       1956.0                  105
# 2                        Krauss-Maffei       1970.0                  120
# 3                              Norinco       2014.0                  125
# 4                              Norinco       2014.0                  125
#
#    Ammunition Main Weapon  Auxiliary Gun Caliber Ammunition Auxiliary Gun  \
# 0                      68                   7.62                   3000.0
# 1                      51                   7.62                   2750.0
# 2                      42                   7.62                   2375.0
# 3                      38                   7.62                   3000.0
# 4                      38                   7.62                   3000.0
#
#    AA Gun Caliber  Ammunition AA Gun
# 0            7.62             3000.0
# 1            7.62             2750.0
# 2            7.62             2375.0
# 3           12.70              500.0
# 4           12.70              500.0
#
# [5 rows x 29 columns]

# %% [markdown]
# Como se puede ver con el "df.head()" muestra las 5 primeras filas.

# %%
max_range = df["Range (km)"].max()
print(max_range)
# Out:
# 700

# %% [markdown]
# Con esto logramos sacar el rango maximo del dataset.

# %%
fila_max = df[df["Range (km)"] == df["Range (km)"].max()]
print(fila_max)
# Out:
#     Model Name Origin Country  Crew  Range (km)  Max Road Speed (km/hr)  \
# 9  M-95 Degman        Croatia     3         700                    72.0
#
#    Power-to-weight ratio (h.p./t)  Length (m)  Width (m)  Height (m)  \
# 9                            27.0       10.14        3.6         2.2
#
#    Engine Power (hp)  ... Elevation (Elevation Max)  Traverse Range  \
# 9               1000  ...                      13.0             360
#
#                        Manufactured By  Launch Year  Main Weapon Caliber  \
# 9  Đuro Đaković specijalna vozila d.d.          NaN                  125
#
#    Ammunition Main Weapon  Auxiliary Gun Caliber Ammunition Auxiliary Gun  \
# 9                      42                   12.7                    360.0
#
#    AA Gun Caliber  Ammunition AA Gun
# 9            7.62             2000.0
#
# [1 rows x 29 columns]

# %% [markdown]
# Con esto lo que conseguimos es mostrar que tanque tiene el mayor rango, que en este caso es el tanque M-95 Degman de la nacion Croata.

# %%
fila_max = df[df["Range (km)"] == df["Range (km)"].max()]
print(fila_max[["Model Name", "Range (km)"]])
# Out:
#     Model Name  Range (km)
# 9  M-95 Degman         700

# %% [markdown]
# Esto de aqui es una forma mas precisa de saber cual es el tanque con el mayor rango.

# %%
sns.scatterplot(data=df, x="Length (m)", y="Width (m)")
# Out:
# <Axes: xlabel='Length (m)', ylabel='Width (m)'>
